# %%
# !pip install -U tensorflow-io==0.16.0
# restart runtime
os.kill(os.getpid(), 9)

# %% [markdown]
# # **Libraries & Load Data**

# %%
from google.colab import drive
drive.mount('/content/drive/')

import os
import sys
import random
import pandas as pd
# from IPython.display import display
from IPython import display
pd.options.display.max_columns = None
import numpy as np
import datetime
import time

import cv2
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import ImageGrid
plt.style.use("dark_background")

import tensorflow_io as tfio
import tensorflow as tf
import tensorflow.keras.backend as K
print(tf.__version__)


from tensorflow import keras
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import ZeroPadding2D,Convolution2D,MaxPooling2D, Conv2D, LocallyConnected2D
from tensorflow.keras.layers import Dense,Dropout,Softmax,Flatten,Activation,BatchNormalization

auc = tf.keras.metrics.AUC()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# 2.3.4

# %% [markdown]
# ## **LGG**

# %%
# LGG_mask = glob('/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/kaggle_3m_Cropped/*/*_mask*')
# LGG_files = [file.replace('_mask', '') for file in LGG_mask]
# print(LGG_files)
# print(LGG_mask)
# print(len(LGG_files))

# def diagnosis(mask_path):
#   value = np.max(cv2.imread(mask_path,  cv2.IMREAD_GRAYSCALE))
#   return 1 if value > 0 else 0

# START_NAME = 52 #len(/content/drive/My Drive/Nam4_HK2/LV_CT595/kaggle_3m/<---/TCGA_CS_5397_20010315_4.tif)
# LEN_NAME = 21 #len(TCGA_CS_5397_20010315)

# def patient(mask_path, START_NAME, LEN_NAME):
#   return mask_path[START_NAME:START_NAME+LEN_NAME]

# df_LGG = pd.DataFrame({"patient": [patient(x, START_NAME, LEN_NAME) for x in LGG_mask],
#                    "image_path": LGG_files,
#                    "mask_path": LGG_mask,
#                    "diagnosis":[diagnosis(x) for x in LGG_mask]})

# df_LGG_1 = df_LGG[df_LGG['diagnosis']==1]
# df_LGG_0 = df_LGG[df_LGG['diagnosis']==0]
# print(df_LGG_0.shape, df_LGG_1.shape)
# print(type(df_LGG['diagnosis'][0]))

# df_LGG

# %% [markdown]
# ## **LOAD DATA**

# %%
mask_files = glob('/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/*/*FLAIR*/*_mask*')
train_files = [file.replace('_mask', '') for file in mask_files]
print(train_files)
print(mask_files)
print(len(train_files))
print(len(mask_files))
# Out:
# ['/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000000.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000001.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000002.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000003.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000004.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000005.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000007.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000006.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000008.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000009.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000010.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000011.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000012.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000014.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000013.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000015.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000016.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000017.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000018.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000019.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000021.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000020.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT ...
# ['/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000000_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000001_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000002_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000003_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000004_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000005_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000007_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000006_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000008_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000009_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000010_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000011_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000012_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000014_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000013_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000015_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000016_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000017_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000018_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000019_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/ĐÀO VĂN THẮM/Series_008_Ax T2 FLAIR enhflair/IM000021_mask.jpg', '/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processin ...
# 2155
# 2155

# %%
def diagnosis(mask_path):
  value = np.max(cv2.imread(mask_path))
  return 1 if value > 0 else 0

# print(len('/content/drive/My Drive/Nam4_HK2/LV_CT595/Pix2Pix_DHYD_BaiBaoKhoaHoc/Dataset_BenhVien_DHYD_toLGG_Processing/')) #108
START_NAME = 108
LEN_NAME = 35 

def patient(mask_path, START_NAME, LEN_NAME):
  return mask_path[START_NAME:START_NAME+LEN_NAME]

df = pd.DataFrame({"patient": [patient(x, START_NAME, LEN_NAME) for x in mask_files],
                   "image_path": train_files,
                   "mask_path": mask_files,
                   "diagnosis":[diagnosis(x) for x in mask_files]})

# df.diagnosis = df.diagnosis.astype(str)
print(type(df['diagnosis'][0]))
df
# Out:
# <class 'numpy.int64'>
#                                   patient  \
# 0     essing/ĐÀO VĂN THẮM/Series_008_
# 1     essing/ĐÀO VĂN THẮM/Series_008_
# 2     essing/ĐÀO VĂN THẮM/Series_008_
# 3     essing/ĐÀO VĂN THẮM/Series_008_
# 4     essing/ĐÀO VĂN THẮM/Series_008_
# ...                                   ...
# 2150  essing/NGUYỄN VĂN MUNG/Series_00
# 2151  essing/NGUYỄN VĂN MUNG/Series_00
# 2152  essing/NGUYỄN VĂN MUNG/Series_00
# 2153  essing/NGUYỄN VĂN MUNG/Series_00
# 2154  essing/NGUYỄN VĂN MUNG/Series_00
#
#                                              image_path  \
# 0     /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 1     /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 2     /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 3     /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 4     /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# ...                                                 ...
# 2150  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 2151  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 2152  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 2153  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 2154  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
#
#                                               mask_path  diagnosis
# 0     /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...          0
# 1     /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...          0
# 2     /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...          0
# 3     /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...          1
# 4     /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...          1
# ...                                                 ...        ...
# 2150  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...          0
# 2151  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...          0
# 2152  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...          0
# 2153  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...          0
# 2154  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...          0
#
# [2155 rows x 4 columns]

# %% [markdown]
# ## **Data Distribution & Visualization**

# %%
# Plot
ax = df.diagnosis.value_counts().plot(kind='bar',
                                      stacked=True,
                                      figsize=(10, 6),
                                     color=["violet", "lightseagreen"])


ax.set_xticklabels(["Positive", "Negative"], rotation=45, fontsize=12);
ax.set_ylabel('Total Images', fontsize = 12)
ax.set_title("Distribution of data grouped by diagnosis",fontsize = 18, y=1.05)

# Annotate
for i, rows in enumerate(df.diagnosis.value_counts().values):
    ax.annotate(int(rows), xy=(i, rows-12), 
                rotation=0, color="white", 
                ha="center", verticalalignment='bottom', 
                fontsize=15, fontweight="bold")
    
ax.text(1.2, 2550, f"Total {len(df)} images", size=15,
        color="black",
         ha="center", va="center",
         bbox=dict(boxstyle="round",
                   fc=("lightblue"),
                   ec=("black"),
                   )
         );

# %%
# Data
patients_by_diagnosis = df.groupby(['patient', 'diagnosis'])['diagnosis'].size().unstack().fillna(0)
patients_by_diagnosis.columns = ["Positive", "Negative"]

# Plot
ax = patients_by_diagnosis.plot(kind='bar',stacked=True,
                                figsize=(18, 10),
                                color=["mediumvioletred", "springgreen"], 
                                alpha=0.9)
ax.legend(fontsize=20);
ax.set_xlabel('Patients',fontsize = 20)
ax.set_ylabel('Total Images', fontsize = 20)
ax.set_title("Distribution of data grouped by patient and diagnosis",fontsize = 25, y=1.005)

# # Annotations
# for i, rows in enumerate(patients_by_diagnosis.values):
#     plt.annotate(int(rows[0]), xy=(i, rows[0]+1), rotation=90, color="white")
#     plt.annotate(int(rows[1]), xy=(i, rows[1]+1), rotation=90, color="aqua");
# Out:
# Text(0.5, 1.005, 'Distribution of data grouped by patient and diagnosis')

# %%
# Visualization (3 positive - 2 negative)

sample_df_positive = df[df["diagnosis"] == 1].sample(3)
sample_df_negative = df[df["diagnosis"] == 0].sample(2)
sample_df = sample_df_positive.append(sample_df_negative, ignore_index=True).values
sample_imgs = []
for i, data in enumerate(sample_df):
    #print(data)
    img = cv2.resize(cv2.imread(data[1]), (512, 512))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(cv2.imread(data[2]), (512, 512))
    sample_imgs.extend([img, mask])


sample_imgs_arr = np.hstack(np.array(sample_imgs[::2]))
sample_masks_arr = np.hstack(np.array(sample_imgs[1::2]))

# Plot
fig = plt.figure(figsize=(25., 25.))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(2, 1),  # creates 2x2 grid of axes
                 axes_pad=0.1,  # pad between axes in inch.
                 )


grid[0].imshow(sample_imgs_arr, cmap='gray')
grid[0].set_title("Images", fontsize=15)
grid[0].axis("off")
grid[1].imshow(sample_masks_arr)
grid[1].set_title("Masks", fontsize=15, y=0.9)
grid[1].axis("off")
plt.show()

# %% [markdown]
# ## **Train/Test/Val**
#
#
# Có tổng 139 BN - 106 BN co bat thuong

# %%
#SPLIT DATA
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.2, random_state=20)  # 1, 10, 20, 50, 100

df_train, df_val = train_test_split(df_train, test_size=0.2, random_state=20) # 1, 10, 20, 50, 100

# shuffle
df_train = df_train.sample(frac=1).reset_index(drop=True)
df_val = df_val.sample(frac=1).reset_index(drop=True)
df_test = df_test.sample(frac=1).reset_index(drop=True)


# print(df_train.shape, (df_train[df_train['diagnosis']==1]).shape)
# print(df_val.shape, (df_val[df_val['diagnosis']==1]).shape)
# print(df_test.shape, (df_test[df_test['diagnosis']==1]).shape)

# Co bat thuong
df_train_1 = df_train[df_train['diagnosis']==1]
#K bat thuong
df_train_0 = df_train[df_train['diagnosis']==0]

print(df_train_0.shape, df_train_1.shape)
print(df_val.shape, (df_val[df_val['diagnosis']==1]).shape)
print(df_test.shape, (df_test[df_test['diagnosis']==1]).shape)

#split 1
# (431, 4) (121, 4)
#Split 10
# (431, 4) (120, 4)
#Split 20
# (431, 4) (107, 4)
#Split 50
# (431, 4) (129, 4)
#Split 100
# (431, 4) (126, 4)
# Out:
# (983, 4) (396, 4)
# (345, 4) (101, 4)
# (431, 4) (107, 4)

# %% [markdown]
# ## **Load Images/Masks with tf.data**

# %% [markdown]
# **Load test_image**

# %%
########## Load IMG/MASK
def load_imagemask(path_image, path_mask):


  image = tf.io.read_file(path_image)
  image = tf.io.decode_jpeg(image)
  image = tf.image.resize(image, (224, 224)) #Resize (512->256)
  # image = image[:,:,0]
  # image = image[..., tf.newaxis]


  # mask = tf.io.read_file(path_mask)
  # mask = tf.io.decode_jpeg(mask)
  # mask = tf.image.resize(mask, (256, 256))
  # mask = mask[:,:,0]
  # mask = mask[..., tf.newaxis]


  image = tf.cast(image, tf.float32)
  # mask = tf.cast(mask, tf.float32)


  return image, path_mask


def load_imagemask_tif(path_image, path_mask):

  # image = cv2.imread(path_image, 1)
  # mask = cv2.imread(path_mask, cv2.IMREAD_GRAYSCALE)


  image = tf.io.read_file(path_image)
  image = tfio.experimental.image.decode_tiff(image)
  # image = rgba2rgb(image) # (256,256,4) to (256,256,3)
  # image = tfio.experimental.color.rgba_to_rgb(image)
  image = tf.image.resize(image, (224, 224)) #Resize (512->256)
  image = image[:,:,0]
  image = image[..., tf.newaxis]

  # mask = tf.io.read_file(path_mask)
  # mask = tfio.experimental.image.decode_tiff(mask)
  # # mask = tfio.experimental.color.rgba_to_rgb(mask)
  # # mask = tfio.experimental.color.rgb_to_grayscale(mask)
  # mask = tf.image.resize(mask, (256, 256))
  # mask = mask[:,:,0]
  # mask = mask[..., tf.newaxis]


  image = tf.cast(image, tf.float32)
  # mask = tf.cast(mask, tf.float32)

  return image, path_mask



IMG, LABEL = load_imagemask(df_test['image_path'].tolist()[1], df_test['diagnosis'][1])

# Casting to int for matplotlib to display the images and mask
plt.figure()
plt.imshow(IMG[:,:,0], cmap='gray')
print(LABEL)
# plt.figure()
# plt.imshow(LABEL[:,:,0], cmap='gray')

# print(IMG, LABEL)
print(K.max(IMG)) #0-255
# print(K.max(LABEL))
print(IMG.shape)
# Out:
# 0
# tf.Tensor(254.54643, shape=(), dtype=float32)
# (224, 224, 3)

# %% [markdown]
# **Pre-processing and load dataset**

# %%
# Standardize/Normalize  the images to [-1, 1]
# def standardize(image, mask):
#   image = (image - 127.5) / 127.5
#   # mask = (mask - 127.5) / 127.5

#   return image, mask

# [0,1]
def standardize(image, mask):
  image = image/255
  # mask = mask/255

  return image, mask

def load_image_train_tif(path_image, path_mask):
  image, mask = load_imagemask_tif(path_image, path_mask)
  image, mask = standardize(image, mask)

  return image, mask  


def load_image_train(path_image, path_mask):
  image, mask = load_imagemask(path_image, path_mask)
  image, mask = standardize(image, mask)
  return image, mask



# Data Augmentation
def flip_left_right(input_image, real_image):
  input_image = tf.image.flip_left_right(input_image)
  # real_image = tf.image.flip_left_right(real_image)
  return input_image, real_image

def flip_up_down(input_image, real_image):
  input_image = tf.image.flip_up_down(input_image)
  # real_image = tf.image.flip_up_down(real_image)
  return input_image, real_image

def rotation(input_image, real_image):
  input_image = tf.image.rot90(input_image)
  # real_image = tf.image.rot90(real_image)
  return input_image, real_image


def Aug(input_image, real_image):
  if tf.random.uniform(()) >= 0.3:
    input_image, real_image = flip_left_right(input_image, real_image)
  elif tf.random.uniform(()) < 0.3 and tf.random.uniform(()) >= 0.6:
    input_image, real_image = flip_up_down(input_image, real_image)
  else:
     input_image, real_image = rotation(input_image, real_image)
  return input_image, real_image

# %% [markdown]
# **Build an input pipeline with `tf.data`**

# %%
BATCH_SIZE = 4


# train_dataset = tf.data.Dataset.from_tensor_slices((df_train['image_path'].tolist(), df_train['diagnosis'].tolist()))
# train_dataset = (train_dataset
#                  .map(load_image_train, num_parallel_calls=tf.data.experimental.AUTOTUNE)
#                 )

# 0
train_dataset_0 = tf.data.Dataset.from_tensor_slices((df_train_0['image_path'].tolist(), df_train_0['diagnosis'].tolist()))
train_dataset_0 = (train_dataset_0
                 .map(load_image_train, num_parallel_calls=tf.data.experimental.AUTOTUNE)
                )
print(tf.data.experimental.cardinality(train_dataset_0))

# 1
train_dataset_1 = tf.data.Dataset.from_tensor_slices((df_train_1['image_path'].tolist(), df_train_1['diagnosis'].tolist()))
train_dataset_1 = (train_dataset_1
                 .map(load_image_train, num_parallel_calls=tf.data.experimental.AUTOTUNE)
                )
print(tf.data.experimental.cardinality(train_dataset_1))

# Aug 1
aug_dataset_1 = (train_dataset_1.map(Aug))


train_dataset_1 = train_dataset_1.concatenate(aug_dataset_1)
print(tf.data.experimental.cardinality(train_dataset_1))

#0+1+Aug1
train_dataset = train_dataset_1.concatenate(train_dataset_0)
print(tf.data.experimental.cardinality(train_dataset))


# # LGG
# #0
# train_dataset_LGG_0 = tf.data.Dataset.from_tensor_slices((df_LGG_0['image_path'].tolist(), df_LGG_0['diagnosis'].tolist()))
# train_dataset_LGG_0 = (train_dataset_LGG_0
#                  .map(load_image_train_tif, num_parallel_calls=tf.data.experimental.AUTOTUNE)
#                 )
# print('lgg_0: {}'.format(tf.data.experimental.cardinality(train_dataset_LGG_0)))

# #1
# train_dataset_LGG_1 = tf.data.Dataset.from_tensor_slices((df_LGG_1['image_path'].tolist(), df_LGG_1['diagnosis'].tolist()))
# train_dataset_LGG_1 = (train_dataset_LGG_1
#                  .map(load_image_train_tif, num_parallel_calls=tf.data.experimental.AUTOTUNE)
#                 )
# print('lgg_1: {}'.format(tf.data.experimental.cardinality(train_dataset_LGG_1)))
# # Aug 1
# aug_dataset_LGG_1 = (train_dataset_LGG_1.map(Aug))


# train_dataset_LGG_1 = train_dataset_LGG_1.concatenate(aug_dataset_LGG_1)
# print(tf.data.experimental.cardinality(train_dataset_LGG_1))


# #0+1+Aug1
# train_dataset_LGG_1 = train_dataset_LGG_1.concatenate(train_dataset_LGG_0)
# print(tf.data.experimental.cardinality(train_dataset_LGG_1))

# train_dataset = train_dataset.concatenate(train_dataset_LGG_1)
# print(tf.data.experimental.cardinality(train_dataset))

train_dataset = (train_dataset.shuffle(2000)
                              .batch(BATCH_SIZE, drop_remainder=True))


val_dataset = tf.data.Dataset.from_tensor_slices((df_val['image_path'].tolist(), df_val['diagnosis'].tolist()))
val_dataset = (val_dataset
                 .map(load_image_train)
                 .batch(BATCH_SIZE)
                )

test_dataset = tf.data.Dataset.from_tensor_slices((df_test['image_path'].tolist(), df_test['diagnosis'].tolist()))
print("test: {}".format(tf.data.experimental.cardinality(test_dataset)))
test_dataset = (test_dataset
                 .map(load_image_train)
                 .batch(1)
                )


print(tf.data.experimental.cardinality(train_dataset))
print(tf.data.experimental.cardinality(val_dataset))
print(tf.data.experimental.cardinality(test_dataset))




# Test
image_batch, labels_batch = next(iter(val_dataset.take(1)))
print(image_batch.shape)
print(labels_batch.shape)
IMG_Test = image_batch[0]
LABEL_Test = labels_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(IMG_Test), np.max(IMG_Test))
# print(np.min(LABEL_Test), np.max(LABEL_Test))

# print(IMG_test)
# print(LABEL_test)
print(IMG_Test.shape)
print(LABEL_Test.shape)

plt.figure()
plt.imshow((IMG_Test[:,:,0]+1)/2, cmap='gray')
# plt.figure()
# plt.imshow((LABEL_Test[:,:,0]+1)/2, cmap='gray')
print(LABEL_Test)


# tf.Tensor(1215, shape=(), dtype=int64)
# tf.Tensor(433, shape=(), dtype=int64)
# tf.Tensor(866, shape=(), dtype=int64)
# tf.Tensor(2081, shape=(), dtype=int64)
# lgg_0: 1215
# lgg_1: 866
# test: 203
# tf.Tensor(65, shape=(), dtype=int64)
# tf.Tensor(10, shape=(), dtype=int64)
# tf.Tensor(3, shape=(), dtype=int64)
# Out:
# tf.Tensor(983, shape=(), dtype=int64)
# tf.Tensor(396, shape=(), dtype=int64)
# tf.Tensor(792, shape=(), dtype=int64)
# tf.Tensor(1775, shape=(), dtype=int64)
# test: 431
# tf.Tensor(443, shape=(), dtype=int64)
# tf.Tensor(87, shape=(), dtype=int64)
# tf.Tensor(431, shape=(), dtype=int64)
# (4, 224, 224, 3)
# (4,)
# 0.0015359523 0.9994354
# (224, 224, 3)
# ()
# tf.Tensor(0, shape=(), dtype=int32)

# %% [markdown]
# # **Train Model VGG**

# %%
from tensorflow.keras.applications import EfficientNetB6
effnet = EfficientNetB6(weights='imagenet',include_top=False,input_shape=(224,224,3))

model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(1,activation='sigmoid')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# rescaling_2 (Rescaling)         (None, 224, 224, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# normalization_2 (Normalization) (None, 224, 224, 3)  7           rescaling_2[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 225, 225, 3)  0           normalization_2[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 112, 112, 56) 1512        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 112, 112, 56) 224         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 112, 112, 56) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 112, 112, 56) 504         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 112, 112, 56) 224         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 112, 112, 56) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 56)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 56)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 14)     798         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 56)     840         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 112, 112, 56) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 112, 112, 32) 1792        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 112, 112, 32) 128         block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 112, 112, 32) 288         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 112, 112, 32) 128         block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 112, 112, 32) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 32)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 112, 112, 32) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 112, 112, 32) 1024        block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 112, 112, 32) 128         block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 112, 112, 32) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 112, 112, 32) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 112, 112, 32) 288         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 112, 112, 32) 128         block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 112, 112, 32) 0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 32)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 112, 112, 32) 0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 112, 112, 32) 1024        block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 112, 112, 32) 128         block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (Dropout)          (None, 112, 112, 32) 0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 112, 112, 32) 0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 112, 112, 192 6144        block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 112, 112, 192 768         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 112, 112, 192 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 113, 113, 192 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 56, 56, 192)  1728        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 56, 56, 192)  768         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 56, 56, 192)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 192)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 56, 56, 192)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 56, 56, 40)   7680        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 56, 56, 40)   160         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 56, 56, 240)  9600        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 56, 56, 240)  960         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 56, 56, 240)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 56, 56, 240)  2160        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 56, 56, 240)  960         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 56, 56, 240)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 240)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 56, 56, 240)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 56, 56, 40)   9600        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 56, 56, 40)   160         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 56, 56, 40)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 56, 56, 40)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 56, 56, 240)  9600        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 56, 56, 240)  960         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 56, 56, 240)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 56, 56, 240)  2160        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 56, 56, 240)  960         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 56, 56, 240)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 240)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 56, 56, 240)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 56, 56, 40)   9600        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 56, 56, 40)   160         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 56, 56, 40)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 56, 56, 40)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 56, 56, 240)  9600        block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 56, 56, 240)  960         block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 56, 56, 240)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 56, 56, 240)  2160        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 56, 56, 240)  960         block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 56, 56, 240)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 240)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 56, 56, 240)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 56, 56, 40)   9600        block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 56, 56, 40)   160         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 56, 56, 40)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 56, 56, 40)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 56, 56, 240)  9600        block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 56, 56, 240)  960         block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 56, 56, 240)  0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 56, 56, 240)  2160        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 56, 56, 240)  960         block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 56, 56, 240)  0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 240)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 56, 56, 240)  0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 56, 56, 40)   9600        block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 56, 56, 40)   160         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (Dropout)          (None, 56, 56, 40)   0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 56, 56, 40)   0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_conv (Conv2D)    (None, 56, 56, 240)  9600        block2e_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_bn (BatchNormali (None, 56, 56, 240)  960         block2f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2f_expand_activation (Acti (None, 56, 56, 240)  0           block2f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2f_dwconv (DepthwiseConv2D (None, 56, 56, 240)  2160        block2f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2f_bn (BatchNormalization) (None, 56, 56, 240)  960         block2f_dwconv[0][0]
# __________________________________________________________________________________________________
# block2f_activation (Activation) (None, 56, 56, 240)  0           block2f_bn[0][0]
# __________________________________________________________________________________________________
# block2f_se_squeeze (GlobalAvera (None, 240)          0           block2f_activation[0][0]
# __________________________________________________________________________________________________
# block2f_se_reshape (Reshape)    (None, 1, 1, 240)    0           block2f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2f_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block2f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2f_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block2f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2f_se_excite (Multiply)    (None, 56, 56, 240)  0           block2f_activation[0][0]
#                                                                  block2f_se_expand[0][0]
# __________________________________________________________________________________________________
# block2f_project_conv (Conv2D)   (None, 56, 56, 40)   9600        block2f_se_excite[0][0]
# __________________________________________________________________________________________________
# block2f_project_bn (BatchNormal (None, 56, 56, 40)   160         block2f_project_conv[0][0]
# __________________________________________________________________________________________________
# block2f_drop (Dropout)          (None, 56, 56, 40)   0           block2f_project_bn[0][0]
# __________________________________________________________________________________________________
# block2f_add (Add)               (None, 56, 56, 40)   0           block2f_drop[0][0]
#                                                                  block2e_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 56, 56, 240)  9600        block2f_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 56, 56, 240)  960         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 56, 56, 240)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 59, 59, 240)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 28, 28, 240)  6000        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 28, 28, 240)  960         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 28, 28, 240)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 240)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 28, 28, 240)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 28, 28, 72)   17280       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 28, 28, 72)   288         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 28, 28, 432)  31104       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 28, 28, 432)  1728        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 28, 28, 432)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 28, 28, 432)  10800       block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 28, 28, 432)  1728        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 28, 28, 432)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 432)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 432)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 18)     7794        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 432)    8208        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 28, 28, 432)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 28, 28, 72)   31104       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 28, 28, 72)   288         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 28, 28, 72)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 28, 28, 72)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 28, 28, 432)  31104       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 28, 28, 432)  1728        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 28, 28, 432)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 28, 28, 432)  10800       block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 28, 28, 432)  1728        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 28, 28, 432)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 432)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 432)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 18)     7794        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 432)    8208        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 28, 28, 432)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 28, 28, 72)   31104       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 28, 28, 72)   288         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 28, 28, 72)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 28, 28, 72)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 28, 28, 432)  31104       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 28, 28, 432)  1728        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 28, 28, 432)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 28, 28, 432)  10800       block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 28, 28, 432)  1728        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 28, 28, 432)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 432)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 432)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 18)     7794        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 432)    8208        block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 28, 28, 432)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 28, 28, 72)   31104       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 28, 28, 72)   288         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 28, 28, 72)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 28, 28, 72)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 28, 28, 432)  31104       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 28, 28, 432)  1728        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 28, 28, 432)  0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 28, 28, 432)  10800       block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 28, 28, 432)  1728        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 28, 28, 432)  0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 432)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 432)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 18)     7794        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 432)    8208        block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 28, 28, 432)  0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# __________________________________________________________________________________________________
# block3e_project_conv (Conv2D)   (None, 28, 28, 72)   31104       block3e_se_excite[0][0]
# __________________________________________________________________________________________________
# block3e_project_bn (BatchNormal (None, 28, 28, 72)   288         block3e_project_conv[0][0]
# __________________________________________________________________________________________________
# block3e_drop (Dropout)          (None, 28, 28, 72)   0           block3e_project_bn[0][0]
# __________________________________________________________________________________________________
# block3e_add (Add)               (None, 28, 28, 72)   0           block3e_drop[0][0]
#                                                                  block3d_add[0][0]
# __________________________________________________________________________________________________
# block3f_expand_conv (Conv2D)    (None, 28, 28, 432)  31104       block3e_add[0][0]
# __________________________________________________________________________________________________
# block3f_expand_bn (BatchNormali (None, 28, 28, 432)  1728        block3f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3f_expand_activation (Acti (None, 28, 28, 432)  0           block3f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3f_dwconv (DepthwiseConv2D (None, 28, 28, 432)  10800       block3f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3f_bn (BatchNormalization) (None, 28, 28, 432)  1728        block3f_dwconv[0][0]
# __________________________________________________________________________________________________
# block3f_activation (Activation) (None, 28, 28, 432)  0           block3f_bn[0][0]
# __________________________________________________________________________________________________
# block3f_se_squeeze (GlobalAvera (None, 432)          0           block3f_activation[0][0]
# __________________________________________________________________________________________________
# block3f_se_reshape (Reshape)    (None, 1, 1, 432)    0           block3f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3f_se_reduce (Conv2D)      (None, 1, 1, 18)     7794        block3f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3f_se_expand (Conv2D)      (None, 1, 1, 432)    8208        block3f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3f_se_excite (Multiply)    (None, 28, 28, 432)  0           block3f_activation[0][0]
#                                                                  block3f_se_expand[0][0]
# __________________________________________________________________________________________________
# block3f_project_conv (Conv2D)   (None, 28, 28, 72)   31104       block3f_se_excite[0][0]
# __________________________________________________________________________________________________
# block3f_project_bn (BatchNormal (None, 28, 28, 72)   288         block3f_project_conv[0][0]
# __________________________________________________________________________________________________
# block3f_drop (Dropout)          (None, 28, 28, 72)   0           block3f_project_bn[0][0]
# __________________________________________________________________________________________________
# block3f_add (Add)               (None, 28, 28, 72)   0           block3f_drop[0][0]
#                                                                  block3e_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 28, 28, 432)  31104       block3f_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 28, 28, 432)  1728        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 28, 28, 432)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 29, 29, 432)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 14, 14, 432)  3888        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 14, 14, 432)  1728        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 14, 14, 432)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 432)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# ...
# block6j_bn (BatchNormalization) (None, 7, 7, 2064)   8256        block6j_dwconv[0][0]
# __________________________________________________________________________________________________
# block6j_activation (Activation) (None, 7, 7, 2064)   0           block6j_bn[0][0]
# __________________________________________________________________________________________________
# block6j_se_squeeze (GlobalAvera (None, 2064)         0           block6j_activation[0][0]
# __________________________________________________________________________________________________
# block6j_se_reshape (Reshape)    (None, 1, 1, 2064)   0           block6j_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6j_se_reduce (Conv2D)      (None, 1, 1, 86)     177590      block6j_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6j_se_expand (Conv2D)      (None, 1, 1, 2064)   179568      block6j_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6j_se_excite (Multiply)    (None, 7, 7, 2064)   0           block6j_activation[0][0]
#                                                                  block6j_se_expand[0][0]
# __________________________________________________________________________________________________
# block6j_project_conv (Conv2D)   (None, 7, 7, 344)    710016      block6j_se_excite[0][0]
# __________________________________________________________________________________________________
# block6j_project_bn (BatchNormal (None, 7, 7, 344)    1376        block6j_project_conv[0][0]
# __________________________________________________________________________________________________
# block6j_drop (Dropout)          (None, 7, 7, 344)    0           block6j_project_bn[0][0]
# __________________________________________________________________________________________________
# block6j_add (Add)               (None, 7, 7, 344)    0           block6j_drop[0][0]
#                                                                  block6i_add[0][0]
# __________________________________________________________________________________________________
# block6k_expand_conv (Conv2D)    (None, 7, 7, 2064)   710016      block6j_add[0][0]
# __________________________________________________________________________________________________
# block6k_expand_bn (BatchNormali (None, 7, 7, 2064)   8256        block6k_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6k_expand_activation (Acti (None, 7, 7, 2064)   0           block6k_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6k_dwconv (DepthwiseConv2D (None, 7, 7, 2064)   51600       block6k_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6k_bn (BatchNormalization) (None, 7, 7, 2064)   8256        block6k_dwconv[0][0]
# __________________________________________________________________________________________________
# block6k_activation (Activation) (None, 7, 7, 2064)   0           block6k_bn[0][0]
# __________________________________________________________________________________________________
# block6k_se_squeeze (GlobalAvera (None, 2064)         0           block6k_activation[0][0]
# __________________________________________________________________________________________________
# block6k_se_reshape (Reshape)    (None, 1, 1, 2064)   0           block6k_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6k_se_reduce (Conv2D)      (None, 1, 1, 86)     177590      block6k_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6k_se_expand (Conv2D)      (None, 1, 1, 2064)   179568      block6k_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6k_se_excite (Multiply)    (None, 7, 7, 2064)   0           block6k_activation[0][0]
#                                                                  block6k_se_expand[0][0]
# __________________________________________________________________________________________________
# block6k_project_conv (Conv2D)   (None, 7, 7, 344)    710016      block6k_se_excite[0][0]
# __________________________________________________________________________________________________
# block6k_project_bn (BatchNormal (None, 7, 7, 344)    1376        block6k_project_conv[0][0]
# __________________________________________________________________________________________________
# block6k_drop (Dropout)          (None, 7, 7, 344)    0           block6k_project_bn[0][0]
# __________________________________________________________________________________________________
# block6k_add (Add)               (None, 7, 7, 344)    0           block6k_drop[0][0]
#                                                                  block6j_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 7, 7, 2064)   710016      block6k_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 7, 7, 2064)   8256        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 7, 7, 2064)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 7, 7, 2064)   18576       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 7, 7, 2064)   8256        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 7, 7, 2064)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 2064)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 2064)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 86)     177590      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 2064)   179568      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 7, 7, 2064)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 7, 7, 576)    1188864     block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 7, 7, 576)    2304        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 7, 7, 3456)   1990656     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 7, 7, 3456)   13824       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 7, 7, 3456)   0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 7, 7, 3456)   31104       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 7, 7, 3456)   13824       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 7, 7, 3456)   0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 3456)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 3456)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 144)    497808      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 3456)   501120      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 7, 7, 3456)   0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 7, 7, 576)    1990656     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 7, 7, 576)    2304        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 7, 7, 576)    0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 7, 7, 576)    0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_expand_conv (Conv2D)    (None, 7, 7, 3456)   1990656     block7b_add[0][0]
# __________________________________________________________________________________________________
# block7c_expand_bn (BatchNormali (None, 7, 7, 3456)   13824       block7c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7c_expand_activation (Acti (None, 7, 7, 3456)   0           block7c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7c_dwconv (DepthwiseConv2D (None, 7, 7, 3456)   31104       block7c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7c_bn (BatchNormalization) (None, 7, 7, 3456)   13824       block7c_dwconv[0][0]
# __________________________________________________________________________________________________
# block7c_activation (Activation) (None, 7, 7, 3456)   0           block7c_bn[0][0]
# __________________________________________________________________________________________________
# block7c_se_squeeze (GlobalAvera (None, 3456)         0           block7c_activation[0][0]
# __________________________________________________________________________________________________
# block7c_se_reshape (Reshape)    (None, 1, 1, 3456)   0           block7c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7c_se_reduce (Conv2D)      (None, 1, 1, 144)    497808      block7c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7c_se_expand (Conv2D)      (None, 1, 1, 3456)   501120      block7c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7c_se_excite (Multiply)    (None, 7, 7, 3456)   0           block7c_activation[0][0]
#                                                                  block7c_se_expand[0][0]
# __________________________________________________________________________________________________
# block7c_project_conv (Conv2D)   (None, 7, 7, 576)    1990656     block7c_se_excite[0][0]
# __________________________________________________________________________________________________
# block7c_project_bn (BatchNormal (None, 7, 7, 576)    2304        block7c_project_conv[0][0]
# __________________________________________________________________________________________________
# block7c_drop (Dropout)          (None, 7, 7, 576)    0           block7c_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_add (Add)               (None, 7, 7, 576)    0           block7c_drop[0][0]
#                                                                  block7b_add[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 7, 7, 2304)   1327104     block7c_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 7, 7, 2304)   9216        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 7, 7, 2304)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2304)         0           top_activation[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 2304)         0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            2305        dropout_2[0][0]
# ==================================================================================================
# Total params: 40,962,448
# Trainable params: 40,738,009
# Non-trainable params: 224,439
# __________________________________________________________________________________________________

# %%
def f1_metric(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
    
def specificity(y_true, y_pred):
    neg_y_true = 1 - y_true
    neg_y_pred = 1 - y_pred
    fp = K.sum(neg_y_true * y_pred)
    tn = K.sum(neg_y_true * neg_y_pred)
    specificity = tn / (tn + fp + K.epsilon())
    return specificity

#
def perf_measure(y_actual, y_pred):
    TP = 0
    FP = 0
    TN = 0
    FN = 0

    for i in range(len(y_pred)): 
        if y_actual[i]==y_pred[i]==1:
           TP += 1
        if y_pred[i]==1 and y_actual[i]!=y_pred[i]:
           FP += 1
        if y_actual[i]==y_pred[i]==0:
           TN += 1
        if y_pred[i]==0 and y_actual[i]!=y_pred[i]:
           FN += 1

    return(TP, FP, TN, FN)

# %% [markdown]
# ## **Train**

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


model.compile(loss='binary_crossentropy',optimizer = 'Adam', metrics=['accuracy', precision, recall, specificity,  f1_metric])
reduce_lr = ReduceLROnPlateau(monitor = 'val_f1_metric', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)
#early stopping
# es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1)

#save
# mc = tf.keras.callbacks.ModelCheckpoint('/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Classifi/Effi6_split4.h5', monitor='val_f1_metric', verbose=1, mode='auto', save_best_only=True)


# # Phat nang hon khi du doan 1->0

# class_weight={0: 0.3,
#               1: 0.7}


# history = VGG_Classifi.fit(train_dataset, epochs = 100, validation_data = val_dataset, callbacks=[mc], class_weight=class_weight)

history = model.fit(train_dataset, epochs = 50, validation_data = val_dataset, callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 443/443 [==============================] - 82s 186ms/step - loss: 0.2900 - accuracy: 0.5999 - precision: 0.5529 - recall: 0.7334 - specificity: 0.4500 - f1_metric: 0.5918 - val_loss: 0.6062 - val_accuracy: 0.7072 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_specificity: 0.7564 - val_f1_metric: 0.0000e+00
# Epoch 2/50
# 443/443 [==============================] - 78s 177ms/step - loss: 0.2761 - accuracy: 0.6021 - precision: 0.5504 - recall: 0.7660 - specificity: 0.4392 - f1_metric: 0.6017 - val_loss: 0.6550 - val_accuracy: 0.6812 - val_precision: 0.0747 - val_recall: 0.0469 - val_specificity: 0.5608 - val_f1_metric: 0.0544
# Epoch 3/50
# 443/443 [==============================] - ETA: 0s - loss: 0.2467 - accuracy: 0.6620 - precision: 0.6226 - recall: 0.7602 - specificity: 0.5207 - f1_metric: 0.6434
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 443/443 [==============================] - 79s 178ms/step - loss: 0.2467 - accuracy: 0.6620 - precision: 0.6226 - recall: 0.7602 - specificity: 0.5207 - f1_metric: 0.6434 - val_loss: 0.6814 - val_accuracy: 0.6290 - val_precision: 0.0287 - val_recall: 0.0172 - val_specificity: 0.6666 - val_f1_metric: 0.0211
# Epoch 4/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.1967 - accuracy: 0.7799 - precision: 0.7372 - recall: 0.7763 - specificity: 0.6184 - f1_metric: 0.7272 - val_loss: 0.5937 - val_accuracy: 0.7101 - val_precision: 0.2816 - val_recall: 0.2184 - val_specificity: 0.6041 - val_f1_metric: 0.2360
# Epoch 5/50
# 443/443 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.8256 - precision: 0.7673 - recall: 0.7889 - specificity: 0.6551 - f1_metric: 0.7516
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 443/443 [==============================] - 79s 178ms/step - loss: 0.1706 - accuracy: 0.8256 - precision: 0.7673 - recall: 0.7889 - specificity: 0.6551 - f1_metric: 0.7516 - val_loss: 0.6419 - val_accuracy: 0.7043 - val_precision: 0.0115 - val_recall: 0.0057 - val_specificity: 0.7854 - val_f1_metric: 0.0077
# Epoch 6/50
# 443/443 [==============================] - 79s 177ms/step - loss: 0.1331 - accuracy: 0.8843 - precision: 0.8153 - recall: 0.8220 - specificity: 0.7290 - f1_metric: 0.7996 - val_loss: 0.5436 - val_accuracy: 0.7420 - val_precision: 0.3238 - val_recall: 0.2347 - val_specificity: 0.7272 - val_f1_metric: 0.2586
# Epoch 7/50
# 443/443 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9120 - precision: 0.8187 - recall: 0.8375 - specificity: 0.7773 - f1_metric: 0.8133
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 443/443 [==============================] - 78s 177ms/step - loss: 0.1067 - accuracy: 0.9120 - precision: 0.8187 - recall: 0.8375 - specificity: 0.7773 - f1_metric: 0.8133 - val_loss: 0.5765 - val_accuracy: 0.7101 - val_precision: 0.4377 - val_recall: 0.4674 - val_specificity: 0.6502 - val_f1_metric: 0.4279
# Epoch 8/50
# 443/443 [==============================] - 79s 177ms/step - loss: 0.0705 - accuracy: 0.9430 - precision: 0.8538 - recall: 0.8563 - specificity: 0.8259 - f1_metric: 0.8467 - val_loss: 0.5065 - val_accuracy: 0.8087 - val_precision: 0.4952 - val_recall: 0.4674 - val_specificity: 0.7661 - val_f1_metric: 0.4650
# Epoch 9/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9565 - precision: 0.8777 - recall: 0.8836 - specificity: 0.8611 - f1_metric: 0.8733
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 443/443 [==============================] - 79s 178ms/step - loss: 0.0542 - accuracy: 0.9565 - precision: 0.8777 - recall: 0.8836 - specificity: 0.8611 - f1_metric: 0.8733 - val_loss: 0.5342 - val_accuracy: 0.7768 - val_precision: 0.4914 - val_recall: 0.4741 - val_specificity: 0.7537 - val_f1_metric: 0.4646
# Epoch 10/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0458 - accuracy: 0.9667 - precision: 0.8772 - recall: 0.8911 - specificity: 0.8744 - f1_metric: 0.8780 - val_loss: 0.5417 - val_accuracy: 0.8029 - val_precision: 0.5086 - val_recall: 0.4818 - val_specificity: 0.7750 - val_f1_metric: 0.4765
# Epoch 11/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9718 - precision: 0.8499 - recall: 0.8512 - specificity: 0.8732 - f1_metric: 0.8469
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0411 - accuracy: 0.9718 - precision: 0.8499 - recall: 0.8512 - specificity: 0.8732 - f1_metric: 0.8469 - val_loss: 0.5799 - val_accuracy: 0.7855 - val_precision: 0.4962 - val_recall: 0.5010 - val_specificity: 0.7545 - val_f1_metric: 0.4743
# Epoch 12/50
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0387 - accuracy: 0.9678 - precision: 0.8683 - recall: 0.8794 - specificity: 0.8661 - f1_metric: 0.8680 - val_loss: 0.5457 - val_accuracy: 0.8087 - val_precision: 0.5220 - val_recall: 0.4990 - val_specificity: 0.7908 - val_f1_metric: 0.4915
# Epoch 13/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9712 - precision: 0.8676 - recall: 0.8826 - specificity: 0.8714 - f1_metric: 0.8699
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0395 - accuracy: 0.9712 - precision: 0.8676 - recall: 0.8826 - specificity: 0.8714 - f1_metric: 0.8699 - val_loss: 0.5514 - val_accuracy: 0.8145 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7880 - val_f1_metric: 0.4938
# Epoch 14/50
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0333 - accuracy: 0.9786 - precision: 0.8807 - recall: 0.8907 - specificity: 0.9019 - f1_metric: 0.8817 - val_loss: 0.5498 - val_accuracy: 0.8145 - val_precision: 0.5249 - val_recall: 0.4952 - val_specificity: 0.8019 - val_f1_metric: 0.4916
# Epoch 15/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9797 - precision: 0.8988 - recall: 0.9035 - specificity: 0.9034 - f1_metric: 0.8974
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# 443/443 [==============================] - 79s 177ms/step - loss: 0.0323 - accuracy: 0.9797 - precision: 0.8988 - recall: 0.9035 - specificity: 0.9034 - f1_metric: 0.8974 - val_loss: 0.5482 - val_accuracy: 0.8145 - val_precision: 0.5192 - val_recall: 0.4837 - val_specificity: 0.8056 - val_f1_metric: 0.4839
# Epoch 16/50
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0343 - accuracy: 0.9740 - precision: 0.8747 - recall: 0.8781 - specificity: 0.8947 - f1_metric: 0.8725 - val_loss: 0.5526 - val_accuracy: 0.8087 - val_precision: 0.5220 - val_recall: 0.4990 - val_specificity: 0.7945 - val_f1_metric: 0.4915
# Epoch 17/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9695 - precision: 0.8687 - recall: 0.8762 - specificity: 0.8797 - f1_metric: 0.8670
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0403 - accuracy: 0.9695 - precision: 0.8687 - recall: 0.8762 - specificity: 0.8797 - f1_metric: 0.8670 - val_loss: 0.5580 - val_accuracy: 0.8087 - val_precision: 0.5211 - val_recall: 0.4952 - val_specificity: 0.7990 - val_f1_metric: 0.4893
# Epoch 18/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0373 - accuracy: 0.9707 - precision: 0.8860 - recall: 0.8920 - specificity: 0.8979 - f1_metric: 0.8839 - val_loss: 0.5549 - val_accuracy: 0.8145 - val_precision: 0.5249 - val_recall: 0.4952 - val_specificity: 0.8003 - val_f1_metric: 0.4916
# Epoch 19/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9746 - precision: 0.8745 - recall: 0.8772 - specificity: 0.8667 - f1_metric: 0.8726
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0392 - accuracy: 0.9746 - precision: 0.8745 - recall: 0.8772 - specificity: 0.8667 - f1_metric: 0.8726 - val_loss: 0.5585 - val_accuracy: 0.8145 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7938 - val_f1_metric: 0.4938
# Epoch 20/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0380 - accuracy: 0.9752 - precision: 0.8764 - recall: 0.8824 - specificity: 0.8815 - f1_metric: 0.8757 - val_loss: 0.5542 - val_accuracy: 0.8116 - val_precision: 0.5249 - val_recall: 0.4952 - val_specificity: 0.8005 - val_f1_metric: 0.4916
# Epoch 21/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9774 - precision: 0.8822 - recall: 0.8858 - specificity: 0.8962 - f1_metric: 0.8806
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0349 - accuracy: 0.9774 - precision: 0.8822 - recall: 0.8858 - specificity: 0.8962 - f1_metric: 0.8806 - val_loss: 0.5536 - val_accuracy: 0.8116 - val_precision: 0.5163 - val_recall: 0.4875 - val_specificity: 0.7966 - val_f1_metric: 0.4838
# Epoch 22/50
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0352 - accuracy: 0.9791 - precision: 0.8807 - recall: 0.8864 - specificity: 0.8871 - f1_metric: 0.8803 - val_loss: 0.5520 - val_accuracy: 0.8116 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7974 - val_f1_metric: 0.4938
# Epoch 23/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9740 - precision: 0.8905 - recall: 0.9048 - specificity: 0.8791 - f1_metric: 0.8928
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.7714700373261393e-09.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0372 - accuracy: 0.9740 - precision: 0.8905 - recall: 0.9048 - specificity: 0.8791 - f1_metric: 0.8928 - val_loss: 0.5495 - val_accuracy: 0.8116 - val_precision: 0.5249 - val_recall: 0.4952 - val_specificity: 0.8011 - val_f1_metric: 0.4916
# Epoch 24/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0375 - accuracy: 0.9656 - precision: 0.8715 - recall: 0.8879 - specificity: 0.8748 - f1_metric: 0.8743 - val_loss: 0.5518 - val_accuracy: 0.8116 - val_precision: 0.5163 - val_recall: 0.4875 - val_specificity: 0.7942 - val_f1_metric: 0.4838
# Epoch 25/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9718 - precision: 0.8851 - recall: 0.8883 - specificity: 0.8995 - f1_metric: 0.8815
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 5.314410245205181e-10.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0376 - accuracy: 0.9718 - precision: 0.8851 - recall: 0.8883 - specificity: 0.8995 - f1_metric: 0.8815 - val_loss: 0.5615 - val_accuracy: 0.8058 - val_precision: 0.5220 - val_recall: 0.4990 - val_specificity: 0.7816 - val_f1_metric: 0.4915
# Epoch 26/50
# 443/443 [==============================] - 79s 177ms/step - loss: 0.0402 - accuracy: 0.9678 - precision: 0.8600 - recall: 0.8710 - specificity: 0.8808 - f1_metric: 0.8594 - val_loss: 0.5524 - val_accuracy: 0.8145 - val_precision: 0.5249 - val_recall: 0.4952 - val_specificity: 0.8037 - val_f1_metric: 0.4916
# Epoch 27/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9752 - precision: 0.8730 - recall: 0.8717 - specificity: 0.8822 - f1_metric: 0.8681
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.5943230069481729e-10.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0378 - accuracy: 0.9752 - precision: 0.8730 - recall: 0.8717 - specificity: 0.8822 - f1_metric: 0.8681 - val_loss: 0.5542 - val_accuracy: 0.8174 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7972 - val_f1_metric: 0.4938
# Epoch 28/50
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0339 - accuracy: 0.9769 - precision: 0.9074 - recall: 0.9133 - specificity: 0.9019 - f1_metric: 0.9066 - val_loss: 0.5596 - val_accuracy: 0.8145 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7902 - val_f1_metric: 0.4938
# Epoch 29/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9774 - precision: 0.8843 - recall: 0.8973 - specificity: 0.8833 - f1_metric: 0.8857
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.7829690208445185e-11.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0339 - accuracy: 0.9774 - precision: 0.8843 - recall: 0.8973 - specificity: 0.8833 - f1_metric: 0.8857 - val_loss: 0.5467 - val_accuracy: 0.8174 - val_precision: 0.5192 - val_recall: 0.4837 - val_specificity: 0.8061 - val_f1_metric: 0.4839
# Epoch 30/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0365 - accuracy: 0.9723 - precision: 0.8753 - recall: 0.8871 - specificity: 0.8937 - f1_metric: 0.8764 - val_loss: 0.5543 - val_accuracy: 0.8145 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7970 - val_f1_metric: 0.4938
# Epoch 31/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9757 - precision: 0.8758 - recall: 0.8851 - specificity: 0.8909 - f1_metric: 0.8767
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.434890747886719e-11.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0346 - accuracy: 0.9757 - precision: 0.8758 - recall: 0.8851 - specificity: 0.8909 - f1_metric: 0.8767 - val_loss: 0.5541 - val_accuracy: 0.8116 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7946 - val_f1_metric: 0.4938
# Epoch 32/50
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0342 - accuracy: 0.9757 - precision: 0.8947 - recall: 0.8975 - specificity: 0.8929 - f1_metric: 0.8915 - val_loss: 0.5543 - val_accuracy: 0.8116 - val_precision: 0.5220 - val_recall: 0.4990 - val_specificity: 0.7933 - val_f1_metric: 0.4915
# Epoch 33/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9769 - precision: 0.8809 - recall: 0.8915 - specificity: 0.8946 - f1_metric: 0.8821
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.304672243660157e-12.
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0350 - accuracy: 0.9769 - precision: 0.8809 - recall: 0.8915 - specificity: 0.8946 - f1_metric: 0.8821 - val_loss: 0.5557 - val_accuracy: 0.8116 - val_precision: 0.5220 - val_recall: 0.4990 - val_specificity: 0.7918 - val_f1_metric: 0.4915
# Epoch 34/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0362 - accuracy: 0.9718 - precision: 0.8747 - recall: 0.8858 - specificity: 0.8988 - f1_metric: 0.8761 - val_loss: 0.5526 - val_accuracy: 0.8087 - val_precision: 0.5211 - val_recall: 0.4952 - val_specificity: 0.7972 - val_f1_metric: 0.4893
# Epoch 35/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9740 - precision: 0.8965 - recall: 0.9056 - specificity: 0.9058 - f1_metric: 0.8952
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.2914016210563428e-12.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0337 - accuracy: 0.9740 - precision: 0.8965 - recall: 0.9056 - specificity: 0.9058 - f1_metric: 0.8952 - val_loss: 0.5480 - val_accuracy: 0.8116 - val_precision: 0.5220 - val_recall: 0.4990 - val_specificity: 0.7970 - val_f1_metric: 0.4915
# Epoch 36/50
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0341 - accuracy: 0.9752 - precision: 0.8826 - recall: 0.8896 - specificity: 0.8973 - f1_metric: 0.8821 - val_loss: 0.5536 - val_accuracy: 0.8116 - val_precision: 0.5249 - val_recall: 0.4952 - val_specificity: 0.7972 - val_f1_metric: 0.4916
# Epoch 37/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9718 - precision: 0.8932 - recall: 0.8922 - specificity: 0.8901 - f1_metric: 0.8880
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.874204993273289e-13.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0394 - accuracy: 0.9718 - precision: 0.8932 - recall: 0.8922 - specificity: 0.8901 - f1_metric: 0.8880 - val_loss: 0.5507 - val_accuracy: 0.8174 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7983 - val_f1_metric: 0.4938
# Epoch 38/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0329 - accuracy: 0.9757 - precision: 0.8666 - recall: 0.8811 - specificity: 0.8943 - f1_metric: 0.8694 - val_loss: 0.5522 - val_accuracy: 0.8087 - val_precision: 0.5211 - val_recall: 0.4952 - val_specificity: 0.8000 - val_f1_metric: 0.4893
# Epoch 39/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9786 - precision: 0.9074 - recall: 0.9120 - specificity: 0.9098 - f1_metric: 0.9058
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.162261530508052e-13.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0339 - accuracy: 0.9786 - precision: 0.9074 - recall: 0.9120 - specificity: 0.9098 - f1_metric: 0.9058 - val_loss: 0.5524 - val_accuracy: 0.8087 - val_precision: 0.5211 - val_recall: 0.4952 - val_specificity: 0.8002 - val_f1_metric: 0.4893
# Epoch 40/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0405 - accuracy: 0.9678 - precision: 0.8704 - recall: 0.8800 - specificity: 0.8982 - f1_metric: 0.8708 - val_loss: 0.5602 - val_accuracy: 0.8058 - val_precision: 0.5153 - val_recall: 0.4837 - val_specificity: 0.7982 - val_f1_metric: 0.4816
# Epoch 41/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9786 - precision: 0.8800 - recall: 0.8851 - specificity: 0.8964 - f1_metric: 0.8795
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.4867844288938296e-14.
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0335 - accuracy: 0.9786 - precision: 0.8800 - recall: 0.8851 - specificity: 0.8964 - f1_metric: 0.8795 - val_loss: 0.5556 - val_accuracy: 0.8174 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7938 - val_f1_metric: 0.4938
# Epoch 42/50
# 443/443 [==============================] - 79s 178ms/step - loss: 0.0358 - accuracy: 0.9746 - precision: 0.8977 - recall: 0.9029 - specificity: 0.8839 - f1_metric: 0.8947 - val_loss: 0.5548 - val_accuracy: 0.8174 - val_precision: 0.5249 - val_recall: 0.4952 - val_specificity: 0.8006 - val_f1_metric: 0.4916
# Epoch 43/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9678 - precision: 0.8834 - recall: 0.8884 - specificity: 0.9018 - f1_metric: 0.8795
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.0460353083393582e-14.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0363 - accuracy: 0.9678 - precision: 0.8834 - recall: 0.8884 - specificity: 0.9018 - f1_metric: 0.8795 - val_loss: 0.5506 - val_accuracy: 0.8203 - val_precision: 0.5249 - val_recall: 0.4952 - val_specificity: 0.8058 - val_f1_metric: 0.4916
# Epoch 44/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0363 - accuracy: 0.9723 - precision: 0.8664 - recall: 0.8836 - specificity: 0.8916 - f1_metric: 0.8697 - val_loss: 0.5528 - val_accuracy: 0.8116 - val_precision: 0.5220 - val_recall: 0.4990 - val_specificity: 0.7894 - val_f1_metric: 0.4915
# Epoch 45/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9752 - precision: 0.8817 - recall: 0.8907 - specificity: 0.9005 - f1_metric: 0.8820
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 3.138105874196098e-15.
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0345 - accuracy: 0.9752 - precision: 0.8817 - recall: 0.8907 - specificity: 0.9005 - f1_metric: 0.8820 - val_loss: 0.5541 - val_accuracy: 0.8145 - val_precision: 0.5249 - val_recall: 0.4952 - val_specificity: 0.7983 - val_f1_metric: 0.4916
# Epoch 46/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0364 - accuracy: 0.9723 - precision: 0.8856 - recall: 0.8922 - specificity: 0.8987 - f1_metric: 0.8835 - val_loss: 0.5575 - val_accuracy: 0.8174 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.8006 - val_f1_metric: 0.4938
# Epoch 47/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9774 - precision: 0.8847 - recall: 0.8913 - specificity: 0.8930 - f1_metric: 0.8835
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 9.414317622588293e-16.
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0336 - accuracy: 0.9774 - precision: 0.8847 - recall: 0.8913 - specificity: 0.8930 - f1_metric: 0.8835 - val_loss: 0.5547 - val_accuracy: 0.8116 - val_precision: 0.5220 - val_recall: 0.4990 - val_specificity: 0.7989 - val_f1_metric: 0.4915
# Epoch 48/50
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0367 - accuracy: 0.9740 - precision: 0.8864 - recall: 0.8883 - specificity: 0.8952 - f1_metric: 0.8826 - val_loss: 0.5569 - val_accuracy: 0.8145 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7941 - val_f1_metric: 0.4938
# Epoch 49/50
# 443/443 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9746 - precision: 0.8732 - recall: 0.8804 - specificity: 0.8969 - f1_metric: 0.8721
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 2.8242954138314303e-16.
# 443/443 [==============================] - 78s 176ms/step - loss: 0.0357 - accuracy: 0.9746 - precision: 0.8732 - recall: 0.8804 - specificity: 0.8969 - f1_metric: 0.8721 - val_loss: 0.5531 - val_accuracy: 0.8116 - val_precision: 0.5220 - val_recall: 0.4990 - val_specificity: 0.7924 - val_f1_metric: 0.4915
# Epoch 50/50
# 443/443 [==============================] - 78s 177ms/step - loss: 0.0333 - accuracy: 0.9763 - precision: 0.8836 - recall: 0.8973 - specificity: 0.8909 - f1_metric: 0.8864 - val_loss: 0.5538 - val_accuracy: 0.8145 - val_precision: 0.5259 - val_recall: 0.4990 - val_specificity: 0.7946 - val_f1_metric: 0.4938

# %%
# list all data in history
print(history.history.keys())
# accuracy
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# plt.legend(['train'], loc='upper left')
plt.show()

# precison
plt.plot(history.history['precision'], label='train')
plt.plot(history.history['val_precision'], label='val')
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
# plt.legend(['train'], loc='upper left')
plt.show()

# recall
plt.plot(history.history['recall'], label='train')
plt.plot(history.history['val_recall'], label='val')
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
# plt.legend(['train'], loc='upper left')
plt.show()

# specificity
plt.plot(history.history['specificity'], label='train')
plt.plot(history.history['val_specificity'], label='val')
plt.title('model specificity')
plt.ylabel('specificity')
plt.xlabel('epoch')
# plt.legend(['train'], loc='upper left')
plt.show()

# f1_metric
plt.plot(history.history['f1_metric'], label='train')
plt.plot(history.history['val_f1_metric'], label='val')
plt.title('model f1_metric')
plt.ylabel('f1_metric')
plt.xlabel('epoch')
# plt.legend(['train'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.legend(['train'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'specificity', 'f1_metric', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_specificity', 'val_f1_metric', 'lr'])

# %% [markdown]
# ## **Eval**

# %%
model.save('/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Classifi/final/test_split20.h5')

# %%
#Last
VGG_Classifi = tf.keras.models.load_model ('/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Classifi/final/test_split20.h5', custom_objects={"precision": precision, "recall": recall, 'specificity': specificity, "f1_metric": f1_metric})

test_loss, test_acc, test_pre, test_recall, test_specificity, test_f1 = VGG_Classifi.evaluate(test_dataset, verbose=2)

t_TP = 0
t_FP = 0
t_TN = 0
t_FN = 0
for image_batch, labels_batch in test_dataset:
# image_batch, labels_batch = next(iter(test_dataset.take(1)))

  predictions_VGG = VGG_Classifi.predict(image_batch)

  y_pred_VGG = []
  # for i in predictions_VGG:
  #   y_pred_VGG.append(np.argmax(i))

  for i in predictions_VGG:
    if i>=0.5:
      y_pred_VGG.append(1)
    else:
      y_pred_VGG.append(0) 


  # print("y_pred with VGG-Face")
  # print(y_pred_VGG) #y_pred
  # print(labels_batch.numpy().tolist()) #Y_test
  # print("y_test")

  TP, FP, TN, FN = perf_measure(labels_batch.numpy().tolist(), y_pred_VGG)
  # print(y_pred_VGG.count(0), y_pred_VGG.count(1), labels_batch.numpy().tolist().count(0), labels_batch.numpy().tolist().count(1))
  t_TP += TP
  t_FP += FP
  t_TN += TN
  t_FN += FN
  # print(TP, FP, TN, FN)

print(t_TP, t_FP, t_TN, t_FN)


# Split_1
# 88	27	283	33       # 94 22 288 27 (0.7/0,3)  # 89 28 282 32 (0.8/0.2)
# 87	25	286	33       # 85 19 292 35 (0.7/0.3)
# 78	27	297	29       # 74 40 284 33
# 90	26	276	39 
# 91	24	281	35
# Out:
# 431/431 - 13s - loss: 0.4053 - accuracy: 0.8306 - precision: 0.1717 - recall: 0.1717 - specificity: 0.6363 - f1_metric: 0.1717
# 74 40 284 33

# %%
# # Load model Best
# #DHYD
# # saved_model = tf.keras.models.load_model ('/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Classifi/VGG_Classificaion.h5', custom_objects={"precision": precision, "recall": recall, 'specificity': specificity, "f1_metric": f1_metric})
# #DHYD+LGG
# saved_model = tf.keras.models.load_model ('/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Classifi/LGG_VGG_Classificaion_Lan4.h5', custom_objects={"precision": precision, "recall": recall, 'specificity': specificity, "f1_metric": f1_metric})

# test_loss, test_acc, test_pre, test_recall, test_specificity, test_f1 = saved_model.evaluate(test_dataset, verbose=2)
# # print('\nTest accuracy:', test_acc)
# # print('\nTest loss:', test_loss)

# t_TP = 0
# t_FP = 0
# t_TN = 0
# t_FN = 0
# for image_batch, labels_batch in test_dataset:
# # image_batch, labels_batch = next(iter(test_dataset.take(1)))

#   predictions_VGG = saved_model.predict(image_batch)

#   y_pred_VGG = []
#   # for i in predictions_VGG:
#   #   y_pred_VGG.append(np.argmax(i))

#   for i in predictions_VGG:
#     if i>=0.5:
#       y_pred_VGG.append(1)
#     else:
#       y_pred_VGG.append(0) 


#   print("y_pred with VGG-Face")
#   print(y_pred_VGG) #y_pred
#   print(labels_batch.numpy().tolist()) #Y_test
#   print("y_test")

#   TP, FP, TN, FN = perf_measure(labels_batch.numpy().tolist(), y_pred_VGG)
#   # print(y_pred_VGG.count(0), y_pred_VGG.count(1), labels_batch.numpy().tolist().count(0), labels_batch.numpy().tolist().count(1))
#   t_TP += TP
#   t_FP += FP
#   t_TN += TN
#   t_FN += FN
#   # print(TP, FP, TN, FN)

# print(t_TP, t_FP, t_TN, t_FN)

# %% [markdown]
# # **Lấy ảnh có bất thường -> tìm vị trí bất thường**

# %%
#DHYD
# best_model = tf.keras.models.load_model ('/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Classifi/VGG_Classificaion.h5', custom_objects={"precision": precision, "recall": recall, 'specificity': specificity, "f1_metric": f1_metric})
#DHYD+LGG
best_model = tf.keras.models.load_model ('/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Classifi/final/efib6split_100.h5', custom_objects={"precision": precision, "recall": recall, 'specificity': specificity, "f1_metric": f1_metric})

test_loss, test_acc, test_pre, test_recall, test_specificity, test_f1 = best_model.evaluate(test_dataset, verbose=2)
# Out:
# 431/431 - 12s - loss: 0.4923 - accuracy: 0.8631 - precision: 0.2111 - recall: 0.2111 - specificity: 0.6401 - f1_metric: 0.2111

# %%
df_final = pd.DataFrame(columns=['patient',	'image_path',	'mask_path',	'diagnosis'])

for step, (image_batch, labels_batch) in test_dataset.enumerate():
  predict_img  = best_model.predict(image_batch)
  if predict_img>=0.5:
    step = int(step)
    # print(step)
    # print(df_test.iloc[step:step+1][:])
    df_final = df_final.append(df_test.iloc[step:step+1][:])

print(len(df_final[df_final['diagnosis']==1]))
df_final
# Out:
# 91
#                                  patient  \
# 2    essing/TRẦN THỊ CẤN/Series_007
# 3    essing/ĐỖ THỊ MAI/Series_003_Ax
# 4    essing/ĐẶNG THỊ HÒA/Series_011_
# 12   essing/BÀNH THỊ DIỆU/Series_005
# 18   essing/NGUYỄN THỊ CÓ/Series_007
# ..                                   ...
# 411  essing/NGUYỄN THỊ LÀNH/Series_0
# 419  essing/NGUYỄN NGỌC BÌNH/Series_
# 421  essing/CHÂU THỊ TUYẾT/Series_00
# 424  essing/TÔN KIM NGỌC/Series_008_Ax
# 428  essing/TRƯƠNG THANH TÙNG/Series_
#
#                                             image_path  \
# 2    /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 3    /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 4    /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 12   /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 18   /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# ..                                                 ...
# 411  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 419  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 421  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 424  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
# 428  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...
#
#                                              mask_path diagnosis
# 2    /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...         1
# 3    /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...         1
# 4    /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...         1
# 12   /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...         0
# 18   /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...         1
# ..                                                 ...       ...
# 411  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...         1
# 419  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...         1
# 421  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...         1
# 424  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...         1
# 428  /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLi...         1
#
# [115 rows x 4 columns]

# %%
df_final.to_excel("/content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc/Classifi/final/df_split100.xlsx")

# %% [markdown]
# # **Hyperparameters**

# %%
LAMBDA = 200
GAMMA = 1


#Learning rate
d_lr = 2e-4   
g_lr = 2e-4  

beta_1=0.5

# %% [markdown]
# # **MODEL GAN** - KIEN TRUC UNET
#
# ![UnetAr.png](data:image/png;base64,...)

# %% [markdown]
# ## **Generator**

# %%
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, Concatenate, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import RandomNormal

def downsample(filters, size, apply_batchnorm=True):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
      tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

  if apply_batchnorm:
    result.add(tf.keras.layers.BatchNormalization())

  result.add(tf.keras.layers.LeakyReLU())

  return result
 
def upsample(filters, size, apply_dropout=False):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
    tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                    padding='same',
                                    kernel_initializer=initializer,
                                    use_bias=False))

  result.add(tf.keras.layers.BatchNormalization())

  if apply_dropout:
      result.add(tf.keras.layers.Dropout(0.5))

  result.add(tf.keras.layers.ReLU())

  return result
 
# define the standalone generator model
def Generator():
  inputs = tf.keras.layers.Input(shape=[256, 256, 1])

  down_stack = [
    downsample(64, 4, apply_batchnorm=False),  # (batch_size, 128, 128, 64)
    downsample(128, 4),  # (batch_size, 64, 64, 128)
    downsample(256, 4),  # (batch_size, 32, 32, 256)
    downsample(512, 4),  # (batch_size, 16, 16, 512)
    downsample(512, 4),  # (batch_size, 8, 8, 512)
    downsample(512, 4),  # (batch_size, 4, 4, 512)
    downsample(512, 4),  # (batch_size, 2, 2, 512)

    downsample(512, 4),  # (batch_size, 1, 1, 512)
  ]

  up_stack = [
    upsample(512, 4, apply_dropout=True),  # (batch_size, 2, 2, 1024)
    upsample(512, 4, apply_dropout=True),  # (batch_size, 4, 4, 1024)
    upsample(512, 4, apply_dropout=True),  # (batch_size, 8, 8, 1024)
    upsample(512, 4),  # (batch_size, 16, 16, 1024)
    upsample(256, 4),  # (batch_size, 32, 32, 512)
    upsample(128, 4),  # (batch_size, 64, 64, 256)
    upsample(64, 4),  # (batch_size, 128, 128, 128)
  ]

  initializer = tf.random_normal_initializer(0., 0.02)
  last = tf.keras.layers.Conv2DTranspose(1, 4,
                                         strides=2,
                                         padding='same',
                                         kernel_initializer=initializer,
                                         activation='tanh')  # (batch_size, 256, 256, 1)

  x = inputs

  # Downsampling through the model
  skips = []
  for down in down_stack:
    x = down(x)
    skips.append(x)

  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    x = tf.keras.layers.Concatenate()([x, skip])

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# Generator G
G = Generator()
G.summary()
tf.keras.utils.plot_model(G, show_shapes=True, dpi=64)

# %% [markdown]
# **Test Model Generator**

# %%
# Standardization 
# Img_G_in = (IMG_Test - 127.5) / 127.5
# Img_G_in = IMG_Test/255.0   #Normalization 

gen_output = G(IMG_Test[tf.newaxis, ...], training=False)
# plt.imshow(gen_output[0, ...])
print(gen_output.shape)


# gen_output = np.squeeze(gen_output) #[0->1]
# gen_output = gen_output/ 1.0        #/255
# gen_output[gen_output > 0.5] = 1
# gen_output[gen_output <= 0.5] = 0


plt.imshow(IMG_Test[:,:,0],cmap='gray')
plt.show()

# Generated
# print(gen_output)
print(gen_output.shape)
plt.imshow(gen_output[0,:,:,0],cmap='gray')
plt.show()

# Original
print("Original")
print(LABEL_Test.shape)
plt.imshow(LABEL_Test[:,:,0],cmap='gray')
plt.show()

# %% [markdown]
# ### **Generator Loss Funcion**

# %% [markdown]
# **Binary Cross-Entropy**
#
# ![Binary Cross-Entropy.png](data:image/png;base64,...)
#
#
# y_true = 0 => loss = log(1 - y_pred)
#
# y_true = 1 => loss = log(y_pred)

# %% [markdown]
# **USING keras.backend - losses**

# %%
loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def generator_loss(disc_generated_output, gen_output, target):
  gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

  # Mean absolute error (MAE-L1)
  # l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

  # RMSE - L2
  l1_loss = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(target, gen_output))))

  total_gen_loss = gan_loss + (LAMBDA * l1_loss)

  return total_gen_loss, gan_loss, l1_loss

# %% [markdown]
# **Optimizers Funcion**

# %%
#Optimizers G
generator_optimizer = tf.keras.optimizers.Adam(g_lr, beta_1=beta_1)

# %% [markdown]
# ## **Discriminator**

# %%
# define the discriminator model
def Discriminator():
  initializer = tf.random_normal_initializer(0., 0.02)

  inp = tf.keras.layers.Input(shape=[256, 256, 1], name='input_image')
  tar = tf.keras.layers.Input(shape=[256, 256, 1], name='target_image')

  x = tf.keras.layers.concatenate([inp, tar])  # (batch_size, 256, 256, channels*2)

  down1 = downsample(64, 4, False)(x)  # (batch_size, 128, 128, 64)
  down2 = downsample(128, 4)(down1)  # (batch_size, 64, 64, 128)
  down3 = downsample(256, 4)(down2)  # (batch_size, 32, 32, 256)

  zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3)  # (batch_size, 34, 34, 256)
  conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                kernel_initializer=initializer,
                                use_bias=False)(zero_pad1)  # (batch_size, 31, 31, 512)

  batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

  leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

  zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu)  # (batch_size, 33, 33, 512)

  last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                kernel_initializer=initializer)(zero_pad2)  # (batch_size, 30, 30, 1)

  return tf.keras.Model(inputs=[inp, tar], outputs=last)


D = Discriminator()
D.summary()
tf.keras.utils.plot_model(D, show_shapes=True, dpi=64)

# %% [markdown]
# **Test Model Discriminator**

# %%
# Test D_out

# Standardization 
# Img_in = (IMG_Test - 127.5) / 127.5
# Mask_in = LABEL_Test[:,:,0]
# Mask_in =  (LABEL_Test - 127.5) / 127.5
# Img_G_in = IMG_Test/255.0   #Normalization

#G_out
gen_output = G(IMG_Test[tf.newaxis, ...], training=False)
# print(LABEL_Test.shape)
# print(gen_output.shape)
# print(tf.expand_dims(LABEL_Test, axis=-1).shape)

#D_out

print(IMG_Test[tf.newaxis, ...].shape)
print(gen_output.shape)
disc_out = D([IMG_Test[tf.newaxis, ...], gen_output], training=False)

print(IMG_Test[tf.newaxis, ...].shape)
print(LABEL_Test[tf.newaxis, ...].shape)
disc_out_REAL = D([IMG_Test[tf.newaxis, ...], LABEL_Test[tf.newaxis, ...]], training=False)

print(disc_out.shape)
# print(disc_out[0, ..., -1])
print(disc_out_REAL.shape)
# print(disc_out_REAL[0, ..., -1])


plt.imshow(disc_out[0, ..., -1], vmin=-20, vmax=20, cmap='RdBu_r')
plt.colorbar()

# %% [markdown]
# **USING KERAS**

# %%
def discriminator_loss(disc_real_output, disc_generated_output):
  real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

  generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

  total_disc_loss = real_loss + (GAMMA * generated_loss)

  return total_disc_loss

# %% [markdown]
# **Optimizer Funcion**

# %%
#Optimizers D
discriminator_optimizer = tf.keras.optimizers.Adam(d_lr, beta_1=beta_1)

# %% [markdown]
# # **Generate images**

# %%
def generate_images(model, test_input, tar):
  img = test_input[0]
  target = tar[0]

  prediction = model(test_input, training=True)
  prediction = prediction[:,:,:,0]

  a = np.array(prediction[0])

  plt.figure(figsize=(15, 15))

  display_list = [img[:,:,0], target[:,:,0], a]
  title = ['Input Image', 'Ground Truth', 'Predicted Image']

  for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.title(title[i])
    # Getting the pixel values in the [0, 1] range to plot.
    plt.imshow(display_list[i], cmap='gray')
    plt.axis('off')
  plt.show()


example_input, example_target = next(iter(val_dataset.take(1)))
print(example_input.shape, example_input.shape)
generate_images(G, example_input, example_target)
print(np.min(example_input), np.max(example_input))
print(np.min(example_input), np.max(example_input))

# %% [markdown]
# # **Metrics Accuracy**

# %%
# def dice_coef(y_true, y_pred):
#     y_truef=K.flatten(y_true)
#     y_predf=K.flatten(y_pred)
#     And=K.sum(y_truef* y_predf)
#     return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) ))

# def iou(y_true, y_pred):
#     intersection = K.sum(y_true * y_pred)
#     sum_ = K.sum(y_true + y_pred)
#     jac = (intersection + smooth) / (sum_ - intersection)
#     return jac

# Precision = TruePositive / (TruePositive + FalsePositive)
def Precision(y_true, y_pred): #K phat. khi doan sai 0->1
  y_true = (y_true+1)/2   #[-1,1] to [0,1]
  y_pred = (y_pred+1)/2   #[-1,1] to [0,1]
  y_true = tf.cast((y_true >= 0.5), tf.float32) #> 0.5 = 1, <0.5 = 0
  y_pred = tf.cast((y_pred >= 0.5), tf.float32) #> 0.5 = 1, <0.5 = 0
  # print(y_true)
  # print(y_pred)
  #TruePositive
  TP = y_true*y_pred
  pr = K.sum(TP) / K.sum(y_true)
  if tf.math.is_nan(pr):
     pr = tf.constant(0.0)
  return pr

# iou = true_positives / (true_positives + false_positives + false_negatives)
def IoU(y_true, y_pred):
  y_true = (y_true+1)/2   #[-1,1] to [0,1]
  y_pred = (y_pred+1)/2   #[-1,1] to [0,1]
  y_true = tf.cast((y_true >= 0.5), tf.float32) #> 0.5 = 1, <0.5 = 0
  y_pred = tf.cast((y_pred >= 0.5), tf.float32) #> 0.5 = 1, <0.5 = 0
  TP = y_true*y_pred
  FN = tf.nn.relu(y_pred - y_true) # <0 => = 0
  iou = K.sum(TP) / (K.sum(y_true) + K.sum(FN))
  if tf.math.is_nan(iou):
    iou = tf.constant(0.0)
  return iou

# Dice similarity coefficient (DSC)
# DSC = 2TP / (2TP + FP + FN)


a = tf.constant([[0.0, -1, -0.75, 0], [0, 0, 0, 0]]) # 6 , 7
b = tf.constant([[0.0, 1, -1, 0], [0.5, 0, 1, -0.5]]) #5
print(Precision(a,b))
print(IoU(a,b))

# %% [markdown]
# # **CHECKPOINT**

# %%
# %cd /content/drive/My Drive/Nam4_HK2/LV_CT595/BTLiem_Pix2Pix_DHYD_BaiBaoKhoaHoc
# Save model
#step
checkpoint_dir = 'training_checkpoints/Procesing_Crop_Lan2/Pix2Pix_DHYD+AUG_lan4/'
checkpoint_prefix = os.path.join(checkpoint_dir+"step", "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator= G,
                                 discriminator= D)

#best
checkpoint_prefix_best = os.path.join(checkpoint_dir+"best", "ckpt")
checkpoint_best = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator= G,
                                 discriminator= D)

# Save history of loss funcion
log_dir="log/"

# %% [markdown]
# # **Training**

# %%
@tf.function
# @tf.function(experimental_relax_shapes=True)
def train_step(input_image, target, step,  val_input, val_target):
  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    gen_output = G(input_image, training=True)

    disc_real_output = D([input_image, target], training=True)
    disc_generated_output = D([input_image, gen_output], training=True)

    gen_total_loss, gen_gan_loss, gen_l1_loss = generator_loss(disc_generated_output, gen_output, target)
    disc_loss = discriminator_loss(disc_real_output, disc_generated_output)

  generator_gradients = gen_tape.gradient(gen_total_loss, G.trainable_variables)
  discriminator_gradients = disc_tape.gradient(disc_loss, D.trainable_variables)

  generator_optimizer.apply_gradients(zip(generator_gradients, G.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(discriminator_gradients, D.trainable_variables))

  #Metric
  G_val = G(val_input, training=True)
  iou_acc = IoU(val_target, G_val)
  precision_acc = Precision(val_target, G_val)


  with summary_writer.as_default():
    tf.summary.scalar('gen_total_loss', gen_total_loss, step=step//100)
    tf.summary.scalar('gen_gan_loss', gen_gan_loss, step=step//100)
    tf.summary.scalar('gen_l1_loss', gen_l1_loss, step=step//100)
    tf.summary.scalar('disc_loss', disc_loss, step=step//100)
    tf.summary.scalar('iou_acc', iou_acc, step=step//100)
    tf.summary.scalar('precision_acc', precision_acc, step=step//100)

  return gen_total_loss, gen_gan_loss, gen_l1_loss, disc_loss, iou_acc, precision_acc

# %%
#train with step
def fit(train_ds, val_ds, steps):
  print("batch_size = {}, g_lr = {}, d_lr = {}, beta_1 = {}, LAMBDA = {} ".format(BATCH_SIZE,g_lr, d_lr, beta_1, LAMBDA))
  val_input, val_target = next(iter(val_ds.take(1)))

  start = time.time()

  min_GAN = 10000.0
  step_best = 0
  for step, (input_image, target) in train_ds.repeat().take(steps).enumerate(): # lay lan luot 1 batch_size theo thu tu trong n steps  (take: lay n batchsize, repeat: lap lai ds lai tu dau)
    if (step) % 100 == 0:
      # display.clear_output(wait=True)

      if step != 0:
        print(f'Time taken for 100 steps: {time.time()-start:.2f} sec\n')

      start = time.time()

      generate_images(G, example_input, example_target)
      print(f"Step: {step}")

    total_gen_loss, gen_gan_loss, gen_l1_loss, disc_loss, iou_acc, precision_acc = train_step(input_image, target, step, val_input, val_target)
    if total_gen_loss < min_GAN and step > 5000:
      min_GAN = total_gen_loss
      step_best = step
      # Save 
      checkpoint_best.save(file_prefix=checkpoint_prefix_best)
      print("best step: {}".format(step_best))
      print ('The best                 -             total_gen_loss : {} - gen_gan_loss: {} - gen_l1_loss: {}    ------ disc_loss: {}  ------- IOU: {} - precision_acc:  {}'.format(total_gen_loss, gen_gan_loss, gen_l1_loss, disc_loss, iou_acc, precision_acc))

      # save to .txt
      with open ('best_step.txt','w') as f:
        f.write('Best step:{}  -   total_gen_loss : {} - gen_gan_loss: {} - gen_l1_loss: {}    ------ disc_loss: {}  ------- IOU: {} - precision_acc:  {}'.format(step_best, total_gen_loss, gen_gan_loss, gen_l1_loss, disc_loss, iou_acc, precision_acc))
      
      
    if (step) % 100 == 0:
      print ('total_gen_loss : {} - gen_gan_loss: {} - gen_l1_loss: {}    ------ disc_loss: {}  ------- IOU: {} - precision_acc: {}'.format(total_gen_loss, gen_gan_loss, gen_l1_loss, disc_loss, iou_acc, precision_acc))

    # Training step
    if (step+1) % 1 == 0:
      print('.', end='', flush=True)


    # # Save (checkpoint) the model every 1k steps
    # if (step + 1) % 2000 == 0:
    #   checkpoint.save(file_prefix=checkpoint_prefix)

  print("best step: {}".format(step_best))

# %%
# save history of loss funcion
summary_writer = tf.summary.create_file_writer(
  log_dir + "fit_Process_Crop_lan2/Pix2Pix_DHYD+AUG_lan4")


# fit(train_dataset, val_dataset, 20001)
fit(train_dataset, val_dataset, 4901)

# %% [markdown]
# # **Restore the latest checkpoint and test the network**

# %% [markdown]
# **Run Tensorboard**

# %%
# %load_ext tensorboard
# %tensorboard --logdir {log_dir}

# %%
# !ls {checkpoint_dir+"best"}

# %%
# !ls {checkpoint_dir+"step"}

# %%
# Restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir+"best"))

# %% [markdown]
# # **Generate some images using the test set**

# %% [markdown]
# ## **VAL**

# %%
# Eval Val_ds
sum_Precision = 0.0
sum_IoU = 0.0
len_ds = 0
for img,tar in val_dataset:
  len_ds+=1
  g_out = G(img, training=True)
  pre = Precision(tar,g_out)
  sum_Precision += pre

  iou = IoU(tar,g_out)
  sum_IoU += iou
  print(pre)
  print(iou)

avr_Precision = sum_Precision/len_ds
avr_IoU = sum_IoU/len_ds
print(avr_Precision)
print(avr_IoU)

# %%
# Run the trained model on a few examples from the test set
for inp, tar in val_dataset.take(200):
  generate_images(G, inp, tar)

# %% [markdown]
# ## **TEST**

# %%
# Eval test_ds
sum_Precision = 0.0
sum_IoU = 0.0
len_ds = 0
for img,tar in test_dataset:
  g_out = G(img, training=True)
  pre = Precision(tar,g_out)

  iou = IoU(tar,g_out)
  print(pre)
  print(iou)
  if iou > 0:
    len_ds+=1
    sum_IoU += iou
    sum_Precision += pre

avr_Precision = sum_Precision/len_ds
avr_IoU = sum_IoU/len_ds
print(avr_Precision)
print(avr_IoU)

# %%
# Run the trained model on a few examples from the test set
for inp, tar in test_dataset.take(200):
  generate_images(G, inp, tar)
